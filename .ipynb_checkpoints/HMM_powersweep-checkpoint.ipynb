# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from AlazarPowerSweepData import *

# %%matplotlib qt

if __name__ == "__main__":
    #project_path = r"G:\Shared drives\Quasiparticles_2\NBR07_Oct2022\test_power_sweep" 
    project_path = str(input(r"Path to Measurement Run Root: "))

    power_sweep_obj = AlazarPowerSweepData(project_path)
    power_sweep_obj.start_HMM_fit()
# Out:
# Path to Measurement Run Root: G:\Shared drives\Quasiparticles_2\NBR07_Oct2022\test_power_sweep
# Creating figure paths.....
# Reading and sorting data files.....
# Creating IQ downsampled plots.....
#
# Please review the downsampled IQ plots - G:\Shared drives\Quasiparticles_2\NBR07_Oct2022\test_power_sweep/IQ_downsampled_plots_2_10.pdf
#
# Attenuation below which the system goes non-linear: 4
# Please Ensure the Following Attenuation Configuration is Correct:
#
#
# LO_power = 20
# Splitter = -3
# Fixed_attenuator_1 = -20
# Fixed_attenuator_2 = -30
# DA_fixed = -10
# Fridge_attenuation = -75
# Ecosorb = -3
# Press Y/y if Correct or N/n if not: y
# Please Ensure the Following MetaData is Correct:
#
#
# dateOfMeasurement = 20221005
# Temp = 30
# eccosorb = True
# KandL = True
# rigidCables = True
# JPA = True
# TWPA = True
# ClearingCoupler = False
# sampleRateMHz = 10
# durationSeconds = 5
# f0 = 4.2727
# LOf = 4.27238
# phi = 0.47
# Press Y/y if Correct or N/n if not: y
#
# The power to the device is -125 dBM at the chosen attenuation 4
#
# Number of Modes you want to fit: 2
# C:\Users\LFL\lflPython-github\MeasurementScripts\Quasiparticles\HMM_Analysis\AlazarPowerSweepData.py:72: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   means = plt.ginput(n = self.numModes)
# Starting HMM Analysis.....
# HMM done on attenuation: 4!
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-ea0392781fa6> in <module>
#       6
#       7     power_sweep_obj = AlazarPowerSweepData(project_path)
# ----> 8     power_sweep_obj.start_HMM_fit()
#
# ~\lflPython-github\MeasurementScripts\Quasiparticles\HMM_Analysis\AlazarPowerSweepData.py in start_HMM_fit(self, avgTime, r_unit, intTime, SNRmin)
#     130         means = self.get_initial_QP_means(sampleRateFromData)
#     131         covars = self.get_initial_QP_covars(r_unit)
# --> 132
#     133         print("Starting HMM Analysis.....")
#     134         self.runHMM(means, covars, sampleRateFromData,intTime,SNRmin)
#
# ~\lflPython-github\MeasurementScripts\Quasiparticles\HMM_Analysis\AlazarPowerSweepData.py in runHMM(self, means, covars, sampleRateFromData, intTime, SNRmin)
#     181                 M.transmat_ = np.array([[0.99, 0.009,0.001],[0.03, 0.95,0.02],[0.05,0.05,0.9]])
#     182             else:
# --> 183                 M.transmat_ = np.array([[0.99, 0.01],[0.01, 0.99]])
#     184
#     185             M.fit(data.T)
#
# ~\AppData\Roaming\Python\Python38\site-packages\hmmlearn\base.py in fit(self, X, lengths)
#     493         X = check_array(X)
#     494         self._init(X)
# --> 495         self._check()
#     496
#     497         self.monitor_._reset()
#
# ~\AppData\Roaming\Python\Python38\site-packages\hmmlearn\hmm.py in _check(self)
#     214
#     215         self.means_ = np.asarray(self.means_)
# --> 216         self.n_features = self.means_.shape[1]
#     217
#     218         if self.covariance_type not in COVARIANCE_TYPES:
#
# IndexError: tuple index out of range
